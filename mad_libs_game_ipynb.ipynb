# %% [markdown]
# <a href="https://colab.research.google.com/github/kulsoom234/1-mad-libs-game-python/blob/main/mad_libs_game_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Mad Libs Game In Python***

# %%
# USER INPUT FIELD #
name = input("Enter the girl name: ")
programming_language = input("Enter a programming language: (e.g python , typescript , next.js , html): ")
mentor = input("Enter the mentor name: ")
center = input("Enter the center name: e.g governer house ")

# STORY CREATED #
print("\n here is my little story based on mad libs game!")
print(f"once upon a time, there was a girl named {name}.")
print(f"{name} was very curios and always want to learn new things")
print(f"one day, he decided to learn {programming_language} language at governer house!")
print(f"Luckily {name} found a great mentor name as {mentor} who was an expert in {programming_language}.")
print("And so , his journey continues......!")
# Out:
# Enter the girl name: kulsoom
# Enter a programming language: (e.g python , typescript , next.js , html): python
# Enter the mentor name: asharib
# Enter the center name: e.g governer house
#
#  here is my little story based on mad libs game!
# once upon a time, there was a girl named kulsoom.
# kulsoom was very curios and always want to learn new things
# one day, he decided to learn python language at governer house!
# Luckily kulsoom found a great mentor name as asharib  who was an expert in python.
# And so , his journey continues......!
